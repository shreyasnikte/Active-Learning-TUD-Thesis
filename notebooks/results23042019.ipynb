# %%
import numpy as np
import pandas as pd
import random
import time
from multiprocessing import Pool

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from math import sqrt
import xgboost as xgb

# For data visualization
import matplotlib.pyplot as plt
# from pandas.tools.plotting import autocorrelation_plot
from bokeh.io import output_notebook, show
from bokeh.models import Title
from bokeh.plotting import figure, output_file, show

import seaborn as sns
# %matplotlib inline

from datetime import datetime, timedelta, date
from tqdm import tqdm            #for .py version
# from tqdm import tqdm_notebook as tqdm     # for .ipynb version

# %%
df_preds = pd.read_csv("../results/predictions2019-04-24.csv", sep='\t')
df_actuals = pd.read_csv("../results/actuals2019-04-24.csv", sep='\t')

# %%
# Get error of predictions
df_err = df_actuals - df_preds
df_err.columns
# Out:
# Index(['Unnamed: 0', 'iter1_exp0', 'iter1_exp1', 'iter1_exp2', 'iter1_exp3',
#        'iter1_exp4', 'iter1_exp5', 'iter1_exp6', 'iter1_exp7', 'iter1_exp8',
#        ...
#        'iter6_exp554', 'iter6_exp555', 'iter6_exp556', 'iter6_exp557',
#        'iter6_exp558', 'iter6_exp559', 'iter6_exp560', 'iter6_exp561',
#        'iter6_exp562', 'iter6_exp563'],
#       dtype='object', length=5520)

# %%
output_notebook()
# file_name = "../temp/" + title + ".html"
# output_file(file_name) #Uncom`ment it to save the plot in html file
p=figure(plot_width=800, plot_height=400, title = "Prediction comparison", x_axis_label = "time slot of day", y_axis_label = "energy consumption",)
p.line(df_actuals.index, df_actuals["iter1_exp910"].values, line_width=1, color='blue')
p.line(df_actuals.index, df_preds["iter1_exp910"].values, line_width=1, color='orange')

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2400">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="82071144-b9a0-4bd9-a59e-737dd6d1c819" data-root-id="2401"></div>

# %%
output_notebook()
# file_name = "../temp/" + title + ".html"
# output_file(file_name) #Uncom`ment it to save the plot in html file
p=figure(plot_width=800, plot_height=400, title = "Prediction comparison", x_axis_label = "time slot of day", y_axis_label = "energy consumption",)
p.line(df_err.index, df_err["iter1_exp910"].values, line_width=1, color='blue')

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1241">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ed10bf8d-718a-4b5a-9386-8e0b6ff92a53" data-root-id="1242"></div>

# %%
df = pd.read_csv("../results/generated_data2019-04-24.csv", sep='\t')
df.tail()
# Out:
#                        GMT  AIR_TEMPERATURE  DEWPOINT  MSL_PRESSURE  STN_PRES  \
# 27835  2013-09-19 21:30:00            12.30       9.4       1011.15   1008.15
# 27836  2013-09-19 22:00:00            12.50       9.1       1011.50   1008.50
# 27837  2013-09-19 22:30:00            11.90       8.8       1011.75   1008.75
# 27838  2013-09-19 23:00:00            11.30       8.5       1012.00   1009.00
# 27839  2013-09-19 23:30:00            10.95       8.5       1012.20   1009.20
#
#        VISIBILITY  WETB_TEMP  WIND_DIRECTION  WIND_SPEED  WMO_HR_SUN_DUR  dow  \
# 27835      3250.0      10.85           260.0         7.0             0.0    3
# 27836      3500.0      10.80           270.0         7.0             0.0    3
# 27837      3200.0      10.35           270.0         6.5             0.0    3
# 27838      2900.0       9.90           270.0         6.0             0.0    3
# 27839      2800.0       9.75           265.0         7.0             0.0    3
#
# ...
